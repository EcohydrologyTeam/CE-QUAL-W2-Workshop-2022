# %% [markdown]
# ## Detroit Reservoir: Plot Output Files

# %%
import w2
year = 1900
model_path = ''
plot_control_file = '1_Detroit_output_plots.yaml'
w2.plot_all_files(plot_control_file, model_path, year, filetype=['png', 'pdf'])
